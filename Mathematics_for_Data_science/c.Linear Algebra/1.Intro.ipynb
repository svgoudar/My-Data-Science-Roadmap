# %% [markdown]
# ### 🎯 **What’s covered?**
#
# You introduced a **linear algebra series** focusing on concepts **important for data science, machine learning (ML), and deep learning**, explaining:
#
# * What is linear algebra?
# * Where it’s used in data science & ML.
# * Upcoming core topics.
#
# ---
#
# ### 🔍 **What is Linear Algebra?**
#
# * A **branch of mathematics** that studies:
#
#   * **Scalars, vectors, vector spaces (linear spaces)**
#   * **Matrices and matrix operations**
#   * **Linear transformations**
#   * **Systems of linear equations**
# * Essential for representing and manipulating data using **mathematical objects** (vectors, matrices).
#
# ---
#
# ### 🚀 **Why is it important for Data Science & ML?**
#
# * Used everywhere in data science, ML, deep learning (DL), computer vision (CV), and NLP.
# * Examples:
#
#   * Text is converted to vectors in NLP (embeddings).
#   * Images are represented as matrices (pixels).
#   * Data is modeled in **higher-dimensional spaces**.
#
# ---
#
# ### 🔥 **Main applications (from your talk)**
#
# #### 1️⃣ **Data Representation & Manipulation**
#
# * Data is represented as **vectors and matrices.**
# * Example: house price prediction dataset
#
#   * Features: area, rooms, location → represented as vectors.
#   * The relationship (like how area impacts price) is quantified via **matrix operations**.
# * Important for:
#
#   * Regression (finding relationships via covariance/correlation).
#   * Understanding multi-dimensional data (2D, 3D, even 500D).
#
# #### 2️⃣ **Machine Learning & AI**
#
# * **Model training** involves matrix arithmetic.
#
#   * Example: linear regression uses the equation $y = mx + c$.
#   * Finding optimal $m, c$ is solving linear equations.
# * **Dimensionality Reduction (PCA):**
#
#   * Reduces higher dimensions (say 500D) to lower (2D or 3D) using eigenvalues & eigenvectors.
# * **Neural Networks:**
#
#   * Forward and backward propagation rely on matrix multiplications.
#   * GPUs speed up training by parallelizing matrix operations.
#
# #### 3️⃣ **Computer Graphics**
#
# * Transformations like scaling, rotating, translating images are done using linear algebra.
# * Pixels of images are matrices.
#
# #### 4️⃣ **Optimization**
#
# * In ML & DL, we minimize error functions (loss) to find best-fit lines (or decision boundaries).
# * Algorithms like **gradient descent** solve these optimization problems using derivatives and matrix operations.
#
# ---
#
# ### ✏ **What core topics will be covered?**
#
# ✅ Scalars, vectors, matrices
# ✅ Matrix operations (addition, multiplication)
# ✅ Linear transformations
# ✅ Eigenvalues & eigenvectors (for PCA)
# ✅ How GPUs use tensors for fast computation
# ✅ Gradient descent and optimization
#
# ---
#
# ✅ **Bottom line:**
# Linear algebra is the **foundational math toolset** for almost everything in machine learning, deep learning, computer vision, NLP, and data representation.
# Your series will make it practical by **tying each concept to data science examples.**

# %% [markdown]
# ### 🎯 **Scalars**
#
# * **Definition:** A scalar is a single numerical value that has **magnitude but no direction**.
# * **Examples in daily life:**
#
#   * Speed: 45 km/h (just a magnitude, no direction).
#   * Temperature: 25 °C.
# * **Examples in data science:**
#
#   * The total number of records (count = 5) → scalar.
#   * The average age in a dataset → scalar.
#   * In the equation of simple linear regression, `y = mx + c`:
#
#     * The **intercept `c`** is a scalar.
#
# ---
#
# ### 🎯 **Vectors**
#
# * **Definition (in physics):** A quantity having both **magnitude and direction**.
# * **Definition (in data science):** An **ordered list of numbers** (multi-dimensional data), representing a point in space or record with multiple features.
# * **Examples:**
#
#   * Physics: Velocity = 45 km/h **toward east**.
#   * Data science: Each record in a dataset.
#
#     * E.g. student `[IQ, study_hours] = [90, 3]` is a 2D vector.
#     * The weights of a person over time `[70, 72, 75, 73]` → a 4D vector.
#
# ---
#
# ### 📊 **Visual examples / plots**
#
# #### 1️⃣ Two-dimensional vector example
#
# * Given point `A = (1, 2)`.
# * Plotted on a 2D plane with x-axis and y-axis.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.quiver(0, 0, 1, 2, angles='xy', scale_units='xy', scale=1, color='blue')
plt.xlim(-1, 4)
plt.ylim(-1, 4)
plt.grid()
plt.text(1, 2, 'A(1,2)', fontsize=12, verticalalignment='bottom', horizontalalignment='right')
plt.title("Vector A in 2D space")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ---
#
# #### 2️⃣ Multiple data points as vectors
#
# * Representing records as points in feature space.

# %%
import numpy as np

# Example data: IQ vs study hours
X = np.array([[90, 2], [100, 3], [85, 4], [95, 2.5]])
labels = ['fail', 'pass', 'fail', 'pass']

plt.figure(figsize=(6,6))
for (x, y), label in zip(X, labels):
    color = 'red' if label == 'pass' else 'yellow'
    plt.scatter(x, y, color=color)
    plt.text(x, y+0.1, f"({x},{y})", fontsize=9)

plt.xlabel('IQ')
plt.ylabel('Study Hours')
plt.title('Students represented as vectors in 2D')
plt.grid()
plt.show()

# %% [markdown]
# ---
#
# #### 3️⃣ Example of vector addition
#
# * Moving from `(0,0)` to `(3,3)` by adding vectors.

# %%
plt.figure(figsize=(6,6))
# first move along x-axis
plt.quiver(0, 0, 3, 0, angles='xy', scale_units='xy', scale=1, color='green')
# then move along y-axis
plt.quiver(3, 0, 0, 3, angles='xy', scale_units='xy', scale=1, color='blue')
# direct move
plt.quiver(0, 0, 3, 3, angles='xy', scale_units='xy', scale=1, color='red', linestyle='dashed')

plt.xlim(-1, 5)
plt.ylim(-1, 5)
plt.grid()
plt.text(3, 3, '(3,3)', fontsize=12)
plt.title('Vector addition to reach (3,3)')
plt.show()

# %% [markdown]
# ---
#
# ### 🎮 Examples from real-world / games
#
# * In **GTA** or other games:
#
#   * The car's speed and direction are vectors. When cars collide, physics engines calculate the **resultant vectors** to simulate bouncing, spinning, or explosions.
# * In boating games, the waves act as vectors impacting the boat’s motion.
#
# ---
#
# ### 📝 Important properties discussed
#
# * Each record in a dataset can be represented as a vector in n-dimensional space.
# * Vectors can exist in **2D, 3D, or even 5000D** in machine learning datasets.
# * In high-dimensional data, we often use linear algebra to **reduce dimensions (PCA, SVD, etc.)**.
#
# ---
#
# ### 🚀 Summary table
#
# | Concept     | Definition / Representation                        | Examples                    |
# | ----------- | -------------------------------------------------- | --------------------------- |
# | Scalar      | Single magnitude, no direction                     | Temp=25°C, count=5          |
# | Vector      | Ordered list of numbers (with magnitude+direction) | \[IQ, hours] = \[90,3]      |
# | Unit vector | Vector of magnitude 1, shows direction only        | `i`, `j` in x, y directions |

# %% [markdown]
# ✅ **Summary of your explanation on vector addition and its applications**
#
# ---
#
# ### 📝 Summary
#
# **1. What is vector addition?**
#
# * Vector addition involves adding corresponding components of two vectors.
# * In 2D, for vectors $p_1 = (x_1, y_1)$ and $p_2 = (x_2, y_2)$, addition gives $p_1 + p_2 = (x_1 + x_2, y_1 + y_2)$.
# * You demonstrated with examples:
#
#   * $(-4, 3) + (5, 3) = (1, 6)$
#   * $(-2, -2) + (-1, -1) = (-3, -3)$
#
# ---
#
# **2. Geometric intuition**
#
# * Adding two vectors means moving from the tip of the first vector by the second vector.
# * Visually, you can:
#
#   * Draw the first vector from the origin.
#   * Place the tail of the second vector at the tip of the first.
#   * The resulting point gives the sum vector.
#
# ---
#
# **3. Applications in data science**
#
# * **Sensor data aggregation:**
#
#   * If multiple sensors give readings (as vectors), we add them to get combined sensor values.
# * **NLP (Natural Language Processing):**
#
#   * Words are converted into vectors (embeddings), e.g. using Word2Vec, Bag of Words, TF-IDF.
#   * Adding vectors of words combines meanings, e.g. "data" + "science" = embedding of "data science".
# * **Image processing:**
#
#   * RGB images have 3 channels (R, G, B) represented by vectors.
#   * To convert to grayscale, we sum or average pixel values across channels.
#
# ---
#
# ✅ **Sample plot: vector addition in 2D**
#
# Let’s create a plot for your example:
#
# * $p_1 = (-4, 3)$
# * $p_2 = (5, 3)$
# * $p_1 + p_2 = (1, 6)$
#
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define vectors
origin = np.array([0, 0])
p1 = np.array([4, 3])
p2 = np.array([5, 3])
p_sum = p1 + p2  # (9,6)

plt.figure(figsize=(8,8))

# Plot vector p1 from origin
plt.quiver(*origin, *p1, angles='xy', scale_units='xy', scale=1, color='r', label='p1 = (4,3)')

# Plot vector p2 starting from p1 (tip-to-tail)
plt.quiver(*p1, *p2, angles='xy', scale_units='xy', scale=1, color='g', label='p2 = (5,3) from p1')

# Plot resultant vector from origin to p_sum
plt.quiver(*origin, *p_sum, angles='xy', scale_units='xy', scale=1, color='b', label='p1 + p2 = (9,6)')

# Optional: draw dashed line to show the triangle
plt.plot([p1[0], p_sum[0]], [p1[1], p_sum[1]], 'b--')

# Set plot limits and grid
plt.xlim(-1, 10)
plt.ylim(-1, 8)
plt.grid(True)
plt.legend()
plt.title("Vector Addition in 2D")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ## 📝 Multiplication of Vectors (Dot Product)
#
# ### 📌 Types of vector multiplication used in data science
#
# 1. **Dot Product (Inner Product)** – results in a **scalar**.
# 2. **Element-wise Multiplication** – results in another **vector**.
# 3. **Scalar Multiplication** – scales a **vector by a scalar**.
#
# ---
#
# ## 🎯 Dot Product
#
# ### 🔎 Definition
#
# The **dot product** of two vectors is the **sum of the products of their corresponding components**, resulting in a **scalar**.
#
# $$
# \mathbf{a} \cdot \mathbf{b} = a_1b_1 + a_2b_2 + ... + a_nb_n
# $$
#
# ---
#
# ### 📊 Example calculation
#
# For vectors:
#
# $$
# \mathbf{a} = (2,3), \quad \mathbf{b} = (4,5)
# $$
#
# Dot product:
#
# $$
# (2 \times 4) + (3 \times 5) = 8 + 15 = 23
# $$
#
# ---
#
# ## 📐 Geometric interpretation
#
# ### 🔹 Projection view
#
# The dot product can be viewed as:
#
# $$
# \mathbf{a} \cdot \mathbf{b} = |\mathbf{a}| \times |\mathbf{b}| \times \cos(\theta)
# $$
#
# where $\theta$ is the angle between the vectors.
#
# ---
#
# ## 🖼 Plots to visualize dot product
#
# ### ➡️ 1. Same direction (positive dot product)

# %%
import matplotlib.pyplot as plt
import numpy as np

origin = np.array([0,0])
a = np.array([5,0])
b = np.array([2,2])

plt.figure(figsize=(6,6))
plt.quiver(*origin, *a, color='r', scale=1, scale_units='xy', angles='xy', label='a = (5,0)')
plt.quiver(*origin, *b, color='g', scale=1, scale_units='xy', angles='xy', label='b = (2,2)')
plt.grid()
plt.axis('equal')
plt.legend()
plt.title("Dot product positive: vectors pointing roughly same way")
plt.show()

# %% [markdown]
# * Here dot product $= 5*2 + 0*2 = 10$
# * Both vectors point **roughly in the same direction**, hence **positive dot product**.
#
# ---
#
# ### ➡️ 2. Opposite direction (negative dot product)

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.array([-5,0])
b = np.array([2,2])

plt.figure(figsize=(6,6))
plt.quiver(*origin, *a, color='r', scale=1, scale_units='xy', angles='xy', label='a = (-5,0)')
plt.quiver(*origin, *b, color='g', scale=1, scale_units='xy', angles='xy', label='b = (2,2)')
plt.grid()
plt.axis('equal')
plt.legend()
plt.title("Dot product negative: vectors opposite directions")
plt.show()

# %% [markdown]
# * Dot product $= (-5)*2 + 0*2 = -10$
# * **Opposite directions**, hence **negative dot product**.
#
# ---
#
# ### ➡️ 3. Orthogonal (dot product zero)

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array([5,0])
b = np.array([0,2])

plt.figure(figsize=(6,6))
plt.quiver(*origin, *a, color='r', scale=1, scale_units='xy', angles='xy', label='a = (5,0)')
plt.quiver(*origin, *b, color='g', scale=1, scale_units='xy', angles='xy', label='b = (0,2)')
plt.grid()
plt.axis('equal')
plt.legend()
plt.title("Dot product zero: vectors at 90 degrees")
plt.show()

# %% [markdown]
# * Dot product $= 5*0 + 0*2 = 0$
# * **Perpendicular vectors**, hence **dot product zero**.
#
# ---
#
# ## 🚀 Application: Cosine similarity in recommendation systems
#
# ### 🎬 Example in data science
#
# * Represent movies by feature vectors:
#
# $$
# \text{Avengers} = (1,2,0,3,1),\quad \text{Movie B} = (2,0,1,1,1)
# $$
#
# * Compute cosine similarity:
#
# $$
# \cos \theta = \frac{ \mathbf{a} \cdot \mathbf{b} }{||\mathbf{a}|| \times ||\mathbf{b}||}
# $$
#
# * Dot product:
#
# $$
# (1*2 + 2*0 + 0*1 + 3*1 + 1*1) = 2 + 0 + 0 + 3 + 1 = 6
# $$
#
# * Magnitudes:
#
# $$
# ||a|| = \sqrt{1^2 + 2^2 + 0^2 + 3^2 + 1^2} = \sqrt{1+4+0+9+1}= \sqrt{15}=3.872
# $$
#
# $$
# ||b|| = \sqrt{2^2 + 0^2 + 1^2 + 1^2 + 1^2} = \sqrt{2^2+0+1+1+1} = \sqrt{7}=2.646
# $$
#
# * Cosine similarity:
#
# $$
# \cos \theta = \frac{6}{(3.872)(2.646)} = 0.586
# $$
#
# → Movies are **58.6% similar**, can recommend **Movie B** to a user who liked **Avengers**.

# %% [markdown]
# ## 📝 What is element-wise multiplication?
#
# * **Element-wise multiplication** (also called **Hadamard product**) is when you multiply corresponding elements of two vectors to produce a **new vector of the same dimension**.
#
# For vectors
#
# ```
# A = [1, 2, 3]
# B = [3, 4, 5]
# ```
#
# Element-wise multiplication gives
#
# ```
# A ⊙ B = [1*3, 2*4, 3*5] = [3, 8, 15]
# ```
#
# ✅ Unlike the **dot product**, this does **not produce a scalar**, it returns a **vector of the same size**.
#
# ---
#
# ## 💡 Where is it used?
#
# * In **feature engineering** for datasets (like calculating discounts).
# * In **neural networks**, especially RNNs / LSTMs / GRUs, for gates (forget, input, output gates) which use element-wise multiplication to decide what information to keep or forget.
# * In general **EDA (exploratory data analysis)**, creating new features via element-wise multiplication or subtraction.
#
# ---
#
# ## 🚀 Example from e-commerce
#
# Imagine:
#
# | Product | Cost | Discount (%) |
# | ------- | ---- | ------------ |
# | A       | 1000 | 0.10         |
# | B       | 500  | 0.20         |
# | C       | 200  | 0.15         |
#
# * **Element-wise multiplication** gives discount amount:
#
# ```
# Discount = Cost ⊙ Discount = [1000*0.1, 500*0.2, 200*0.15] = [100, 100, 30]
# ```
#
# * Then final price is
#
# ```
# Final = Cost - Discount = [900, 400, 170]
# ```
#
# ---
#
# # 🐍 Python example with plots
#
# ---
#
# Here’s a simple **Python script with matplotlib plots** to show this visually.
#
# ---
#
# ## ✏️ Code

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
products = ['A', 'B', 'C']
costs = np.array([1000, 500, 200])
discounts = np.array([0.10, 0.20, 0.15])

# Element-wise multiplication to get discount amount
discount_amount = costs * discounts

# Final price after discount
final_price = costs - discount_amount

# -------------------------
# Plotting
# -------------------------
x = np.arange(len(products))

plt.figure(figsize=(10,6))

# Original costs
plt.bar(x - 0.2, costs, width=0.4, label='Original Cost', color='skyblue')

# Discount amounts
plt.bar(x + 0.2, discount_amount, width=0.4, label='Discount Amount', color='lightgreen')

# Final price
for i in range(len(products)):
    plt.text(x[i], final_price[i] + 20, f'Final: {int(final_price[i])}', ha='center', fontsize=10, color='darkblue')

plt.xticks(x, products)
plt.ylabel('Amount ($)')
plt.title('Element-wise multiplication example in Feature Engineering')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ---
#
# ## 🔍 What this shows
#
# * Left bars: original costs
# * Right bars: discount amounts (via element-wise multiplication)
# * Final price labeled above (via element-wise subtraction).
#
# ---

# %% [markdown]
# ## 🎥 **Vector Multiplication & Scaling Concepts**
#
# ### 🚀 1. **Scalar multiplication**
#
# * **Definition:** Multiplying a vector by a scalar (single number).
#
# * **Effect:** Each component of the vector is scaled by that scalar.
#
# * **Example:**
#
#   * Given vector $a = (3, 5, 7)$ and scalar $c = 4$,
#   * Scalar multiplication gives:
#
#     $$
#     c \cdot a = (12, 20, 28)
#     $$
#
# * **Geometric intuition:**
#
#   * If a vector is plotted on a coordinate plane, scalar multiplication stretches or shrinks it.
#   * E.g., vector $(2, 2)$ multiplied by $2$ becomes $(4, 4)$, doubling its length in the same direction.
#
# ---
#
# ### 🎨 2. **Normalization in images**
#
# * **Problem:** Grayscale image pixels range from $0$ to $255$.
#
# * **Goal:** Normalize pixel values to $0$ to $1$ for easier computation (reducing large numbers).
#
# * **How:**
#
#   $$
#   \text{normalized pixel} = \frac{\text{pixel}}{255}
#   $$
#
# * This is also an example of **scalar multiplication**.
#
# ---
#
# ### 📏 3. **Scaling features (standardization example)**
#
# * **Example:** Given a feature vector for height in cm:
#
#   $$
#   h = (160, 170, 180)
#   $$
#
# * To convert to meters, multiply by $0.01$:
#
# $$
# 0.01 \times h = (1.6, 1.7, 1.8)
# $$
#
# * This is scalar multiplication used to **scale units**, making data ready for machine learning or consistent with other features.
#
# ---
#
# ### 🧮 4. **Recap of vector multiplication types**
#
# * **Dot product:** Produces a scalar (inner product).
# * **Element-wise multiplication:** Multiply corresponding elements.
# * **Scalar multiplication:** Multiply entire vector by a scalar, scaling all components.
#
# ---
#
# ✅ **Bottom line:**
# You explained **scalar multiplication of vectors** with numerical & geometric examples, showed how **normalization scales image data**, how **feature scaling adjusts units**, and tied it back to general vector operations.

# %% [markdown]
# ## 🚀 **1. Introduction to matrices**
#
# * A **matrix** is a **rectangular array** of numbers (or symbols) arranged in **rows and columns**.
# * Usually denoted by a capital letter (like **A**), with elements $a_{ij}$ where:
#
#   * $i$ = row index
#   * $j$ = column index
#
# ---
#
# ## 📊 **2. Matrices for data representation**
#
# * In data science, matrices are widely used to represent datasets.
# * Example:
#
#   * A dataset with features: **math score, physics score, biology score** for students.
#   * Each row = scores for a student (record), each column = a feature.
#   * Forms a **3x3 matrix** if you have 3 students and 3 features.
#
# ---
#
# ## 🖼 **3. Images as matrices**
#
# * A grayscale image is represented as a matrix of pixel intensities (0 to 255).
# * Example:
#
#   * A **3x3 grayscale image** → a **3x3 matrix** of pixel values.
#   * 0 = black, 255 = white. Values in between are shades of gray.
#
# ---
#
# ## 🧮 **4. Confusion matrix in machine learning**
#
# * A special **2x2 matrix** used to evaluate classification models.
#
#   * Example:
#
#     * **50** = true positives
#     * **10** = false negatives
#     * **5** = false positives
#     * **35** = true negatives
# * Used to compute accuracy, precision, recall.
#
# ---
#
# ## 🧠 **5. Matrices in neural networks**
#
# * **Forward propagation** involves **matrix multiplication**:
#
#   * Inputs $x_1, x_2$ multiplied by weights $W$ plus bias $b$.
#   * Expressed as:
#
#     $$
#     W^T x + b
#     $$
# * Shapes are important: e.g., 2 inputs connected to 3 neurons → **2x3 weight matrix**.
#
# ---
#
# ## 📈 **6. Matrices in linear regression**
#
# * Regression with multiple features (like study hours & IQ predicting exam scores).
# * Equation in matrix form:
#
# $$
# y = M^T x + c
# $$
#
# * $M$ holds coefficients (slopes for each feature), $x$ holds feature values.
#
# ---
#
# ## 📝 **7. Matrices in NLP**
#
# * Text data (reviews) is converted into vectors (e.g., embeddings).
# * Combined multiple vectors into a **matrix**, which becomes input to ML models.
#
# ---
#
# ## 🎯 **8. Why matrices?**
#
# * Matrices enable **vectorized operations** needed for:
#
#   * Data storage & processing
#   * Mathematical calculations in ML algorithms (like dot products, transformations)
#   * Efficient implementation in frameworks (like NumPy, TensorFlow, PyTorch)

# %% [markdown]
# ## 📌 **Why matrix operations are important?**
#
# * Matrix operations help **manipulate & analyze multi-dimensional data efficiently**.
# * Essential for machine learning, deep learning, and data science workflows.
#
# ---
#
# ## 🚀 **1️⃣ Matrix addition & subtraction**
#
# * ✅ **Definition:** Add or subtract corresponding elements of matrices.
# * ⚠️ **Condition:** Matrices must have **same dimensions**.
# * **Example:**
#
#   * Matrix A (daily sales in Store A) and Matrix B (Store B) — both 3×3.
#   * Add A + B to get combined sales.
#
# ---
#
# ## 🚀 **2️⃣ Scalar multiplication**
#
# * ✅ **Definition:** Multiply every element of a matrix by a scalar value.
# * **Example use case:**
#
#   * Adjust product prices for **inflation** by multiplying each element by a factor (e.g., 1.05 for 5% inflation).
# * Similar technique used in **feature engineering** to scale or adjust data.
#
# ---
#
# ## 🚀 **3️⃣ Matrix multiplication**
#
# * ✅ **Definition:** Dot product of **rows of first matrix** with **columns of second matrix**.
# * ⚠️ **Condition:**
#
#   * If A is of size (m × n) and B is (n × p), multiplication is possible.
#   * Resulting matrix C will be of size (m × p).
#
# ---
#
# ### 🔍 **Detailed example:**
#
# * Given:
#
#   * Matrix A (2 × 3)
#   * Matrix B (3 × 2) \[after transposing to make multiplication possible]
# * Compute each element C<sub>ij</sub> by summing products of row i of A and column j of B.
# * Result: C is a **2 × 2** matrix.
#
# ---
#
# ## 💡 **Other key points discussed:**
#
# * **Transpose:** Switching rows to columns, needed to align dimensions for multiplication.
# * In practice:
#
#   * Used heavily in **deep learning**, **neural networks** (weight & bias operations), **linear regression**, etc.
# * All major machine learning algorithms rely on these operations internally.
