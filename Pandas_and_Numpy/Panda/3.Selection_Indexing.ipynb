# %% [markdown]
# <a href="https://colab.research.google.com/github/svgoudar/My-Data-Science-Roadmap/blob/main/Pandas_and_Numpy/Panda/3.Selection_Indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_loan_applications = pd.read_csv("https://raw.githubusercontent.com/svgoudar/datasets/refs/heads/main/loan_applications.csv")
df_transactions = pd.read_csv("https://raw.githubusercontent.com/svgoudar/datasets/refs/heads/main/transactions.csv")

# %%
df_loan_applications = df_loan_applications.set_index('customer_id')

# %%
df_loan_applications.reset_index(inplace=True)

# %%
df_loan_applications[df_loan_applications['customer_id'] < 'CUST109427']['customer_id'].max()
# Out:
# 'CUST109426'

# %%
df_loan_applications['applicant_age']
# Out:
# 0        28
# 1        44
# 2        56
# 3        27
# 4        50
#          ..
# 49995    55
# 49996    61
# 49997    48
# 49998    62
# 49999    46
# Name: applicant_age, Length: 50000, dtype: int64

# %%
df_loan_applications[['applicant_age','loan_type']]
# Out:
#        applicant_age       loan_type
# 0                 28   Business Loan
# 1                 44        Car Loan
# 2                 56  Education Loan
# 3                 27        Car Loan
# 4                 50   Personal Loan
# ...              ...             ...
# 49995             55  Education Loan
# 49996             61  Education Loan
# 49997             48        Car Loan
# 49998             62   Business Loan
# 49999             46       Home Loan
#
# [50000 rows x 2 columns]

# %%
print(df_loan_applications.iloc[0])
print("\n")
print(df_loan_applications.loc[0])
# Out:
# customer_id                                                         CUST109427
# application_id                            c8bf0bea-70e6-4870-9125-41b8210c527f
# application_date                                                    2023-04-09
# loan_type                                                        Business Loan
# loan_amount_requested                                                 604000.0
# loan_tenure_months                                                          12
# interest_rate_offered                                                    11.66
# purpose_of_loan                                              Medical Emergency
# employment_status                                                      Retired
# monthly_income                                                         34700.0
# cibil_score                                                                714
# existing_emis_monthly                                                   1100.0
# ...

# %%
df = df_loan_applications.set_index('customer_id')

# %% [markdown]
# | Feature          | `.loc`                        | `.iloc`                      |
# | ---------------- | ----------------------------- | ---------------------------- |
# | Indexes by       | **Label names**               | **Integer positions**        |
# | Works with       | Index names & col names       | Row/col numbers (0,1,2)      |
# | Slices are       | **Inclusive** of end          | **Exclusive** of end         |
# | Typical use case | When index/columns have names | When treating as pure matrix |

# %%
df_loan_applications.loc[:10,['customer_id','application_id']]
# Out:
#    customer_id                        application_id
# 0   CUST109427  c8bf0bea-70e6-4870-9125-41b8210c527f
# 1   CUST106146  91224cec-3544-4bc7-ac15-a9792da54c02
# 2   CUST100674  4efcd02d-4a03-4ab7-9bd1-0ff430493d0c
# 3   CUST106466  a61337d4-ba04-4a68-b492-2cb8266e6ed7
# 4   CUST112319  a8d1639e-170b-41b2-826a-55c7dae38d16
# 5   CUST116153  d91cf990-efa1-44ad-94bf-44e6c79d1051
# 6   CUST118841  cd837d7e-98de-4d26-8b6f-f59d7bef9d2a
# 7   CUST109691  63e87083-c21d-4b53-856b-b58b3285b9aa
# 8   CUST106322  7eb31cc3-e1e7-4ef9-ae4e-b86771d60119
# 9   CUST102418  74126982-ef72-40dd-8cc3-5d441cfe7b02
# 10  CUST101535  2cdc104f-abbf-4f8d-b9c1-2e073ed17bb7

# %%
  df_loan_applications.loc[df_loan_applications['customer_id'] < 'CUST101535']
# Out:
#       customer_id                        application_id application_date  \
# 2      CUST100674  4efcd02d-4a03-4ab7-9bd1-0ff430493d0c       2023-05-22
# 11     CUST101333  0e6ce97f-296f-41e7-88a5-0a4951e4262d       2023-11-09
# 18     CUST101064  10bb2424-c9be-4ede-b054-5943e4bed62b       2024-08-26
# 39     CUST100101  d1b05115-e018-4741-8aa8-e5068bcd2484       2023-07-30
# 52     CUST100826  27ab215f-4f9c-492b-9c19-dedef1f690a0       2024-03-23
# ...           ...                                   ...              ...
# 49918  CUST100184  58bf9bbb-70b9-4668-9260-14c168ede7d0       2025-01-01
# 49944  CUST101388  f649f9ed-631d-4b9d-98b4-e875b96d74a5       2023-02-20
# 49951  CUST100444  fe05ce1e-4f64-4227-8497-802b9f8b6eb9       2025-01-12
# 49957  CUST101018  a9c0c7ca-7796-4a72-a524-f0cbc17e82d9       2024-02-10
# 49962  CUST101224  e1bcb9de-02c1-4454-b4e3-39d0d68a6e71       2024-11-15
#
#             loan_type  loan_amount_requested  loan_tenure_months  \
# ...

# %%
df_loan_applications.loc[df_loan_applications['monthly_income'] < 50000,['customer_id','application_id','monthly_income']]
# Out:
#       customer_id                        application_id  monthly_income
# 0      CUST109427  c8bf0bea-70e6-4870-9125-41b8210c527f         34700.0
# 2      CUST100674  4efcd02d-4a03-4ab7-9bd1-0ff430493d0c         14800.0
# 3      CUST106466  a61337d4-ba04-4a68-b492-2cb8266e6ed7         28800.0
# 4      CUST112319  a8d1639e-170b-41b2-826a-55c7dae38d16         43900.0
# 6      CUST118841  cd837d7e-98de-4d26-8b6f-f59d7bef9d2a         47300.0
# ...           ...                                   ...             ...
# 49989  CUST118628  5c2ff689-ef1a-417e-8cff-a07d716f12df         31700.0
# 49995  CUST114840  1d4b1017-e8a1-4a7b-94d1-63e90b05d665         49200.0
# 49996  CUST103055  2984426c-6d0b-437c-9a13-84bf3244c6d4         28600.0
# 49997  CUST119886  cdbc7ad8-0f23-46c4-aaca-619053ad5605         42000.0
# 49998  CUST109088  46a8f901-8005-4ae7-923e-f9d0dc8e0ae8         46700.0
#
# [24717 rows x 3 columns]

# %%
df_loan_applications.loc[df_loan_applications['monthly_income'] < 50000,['customer_id','application_id','monthly_income']]
# Out:
#       customer_id                        application_id  monthly_income
# 0      CUST109427  c8bf0bea-70e6-4870-9125-41b8210c527f         34700.0
# 2      CUST100674  4efcd02d-4a03-4ab7-9bd1-0ff430493d0c         14800.0
# 3      CUST106466  a61337d4-ba04-4a68-b492-2cb8266e6ed7         28800.0
# 4      CUST112319  a8d1639e-170b-41b2-826a-55c7dae38d16         43900.0
# 6      CUST118841  cd837d7e-98de-4d26-8b6f-f59d7bef9d2a         47300.0
# ...           ...                                   ...             ...
# 49989  CUST118628  5c2ff689-ef1a-417e-8cff-a07d716f12df         31700.0
# 49995  CUST114840  1d4b1017-e8a1-4a7b-94d1-63e90b05d665         49200.0
# 49996  CUST103055  2984426c-6d0b-437c-9a13-84bf3244c6d4         28600.0
# 49997  CUST119886  cdbc7ad8-0f23-46c4-aaca-619053ad5605         42000.0
# 49998  CUST109088  46a8f901-8005-4ae7-923e-f9d0dc8e0ae8         46700.0
#
# [24717 rows x 3 columns]

# %%
df_loan_applications[df_loan_applications['cibil_score'] > 720]
# Out:
#       customer_id                        application_id application_date  \
# 2      CUST100674  4efcd02d-4a03-4ab7-9bd1-0ff430493d0c       2023-05-22
# 6      CUST118841  cd837d7e-98de-4d26-8b6f-f59d7bef9d2a       2023-02-02
# 8      CUST106322  7eb31cc3-e1e7-4ef9-ae4e-b86771d60119       2025-05-11
# 11     CUST101333  0e6ce97f-296f-41e7-88a5-0a4951e4262d       2023-11-09
# 14     CUST103082  973a866a-a7bd-4166-8121-a1e220e29a83       2023-12-16
# ...           ...                                   ...              ...
# 49994  CUST115955  c7e837fb-11b8-44d3-a093-45c899cfe38c       2023-11-22
# 49995  CUST114840  1d4b1017-e8a1-4a7b-94d1-63e90b05d665       2024-12-29
# 49996  CUST103055  2984426c-6d0b-437c-9a13-84bf3244c6d4       2022-06-17
# 49997  CUST119886  cdbc7ad8-0f23-46c4-aaca-619053ad5605       2024-12-14
# 49998  CUST109088  46a8f901-8005-4ae7-923e-f9d0dc8e0ae8       2022-12-16
#
#             loan_type  loan_amount_requested  loan_tenure_months  \
# ...

# %%
print(df_loan_applications.iloc[:20,[0,4,5]].sample(2))
print("\n")
print(df_loan_applications.iloc[:20,0:5].sample(2))
# Out:
#    customer_id  loan_amount_requested  loan_tenure_months
# 1   CUST106146               100000.0                 240
# 10  CUST101535               395000.0                  12
#
#
#   customer_id                        application_id application_date  \
# 1  CUST106146  91224cec-3544-4bc7-ac15-a9792da54c02       2023-09-23
# 0  CUST109427  c8bf0bea-70e6-4870-9125-41b8210c527f       2023-04-09
#
#        loan_type  loan_amount_requested
# 1       Car Loan               100000.0
# 0  Business Loan               604000.0

# %%
df_loan_applications.query('loan_amount_requested > 500000').sample(2)

df_loan_applications.query('loan_amount_requested > 500000 and applicant_age < 40').sample(2)
# print("==================")
df_loan_applications.query('loan_type in ["Car Loan", "Education Loan"]').sample(2)
# print("==================")
# Out:
#       customer_id                        application_id application_date  \
# 33060  CUST114258  039f6138-115a-438f-bf64-3bfd62e69546       2024-09-20
# 35200  CUST114006  62251326-af3a-4286-bc98-6dbba11e5910       2025-03-27
#
#             loan_type  loan_amount_requested  loan_tenure_months  \
# 33060        Car Loan               446000.0                 240
# 35200  Education Loan               660000.0                  12
#
#        interest_rate_offered    purpose_of_loan employment_status  \
# 33060                   9.60   Vehicle Purchase          Salaried
# 35200                  11.85  Medical Emergency           Student
#
#        monthly_income  ...  existing_emis_monthly  debt_to_income_ratio  \
# 33060         75400.0  ...                  400.0                  0.53
# 35200         47900.0  ...                 4800.0                 10.02
#
#        property_ownership_status  \
# 33060                     Rented
# 35200                      Owned
#
# ...

# %%
df= df_loan_applications.copy()
df_trans = df_transactions.copy()

# %%
# Select columns by exact names
df.filter(items=['customer_id', 'loan_amount_requested'], axis=1)

# Select columns by regex
df.filter(regex='^loan', axis=1)   # picks all columns starting with 'loan'

# df.set_index('customer_id',inplace=True)
# Select rows by index label list

df.filter(items=[0, 1], axis=0)  # only if customer_id is the index
# Out:
#   customer_id                        application_id application_date  \
# 0  CUST109427  c8bf0bea-70e6-4870-9125-41b8210c527f       2023-04-09
# 1  CUST106146  91224cec-3544-4bc7-ac15-a9792da54c02       2023-09-23
#
#        loan_type  loan_amount_requested  loan_tenure_months  \
# 0  Business Loan               604000.0                  12
# 1       Car Loan               100000.0                 240
#
#    interest_rate_offered    purpose_of_loan employment_status  monthly_income  \
# 0                  11.66  Medical Emergency           Retired         34700.0
# 1                  13.62          Education        Unemployed         51600.0
#
#    ...  existing_emis_monthly  debt_to_income_ratio  \
# 0  ...                 1100.0                  3.17
# 1  ...                    0.0                  0.00
#
#    property_ownership_status  \
# 0                     Rented
# 1                      Owned
#
#                                  residential_address applicant_age  gender  \
# ...

# %%
df[df['loan_type'].isin(['Car Loan', 'Education Loan'])]
# Out:
#       customer_id                        application_id application_date  \
# 1      CUST106146  91224cec-3544-4bc7-ac15-a9792da54c02       2023-09-23
# 2      CUST100674  4efcd02d-4a03-4ab7-9bd1-0ff430493d0c       2023-05-22
# 3      CUST106466  a61337d4-ba04-4a68-b492-2cb8266e6ed7       2024-07-09
# 10     CUST101535  2cdc104f-abbf-4f8d-b9c1-2e073ed17bb7       2024-10-19
# 12     CUST106264  e0b509dc-5357-427d-bd69-681308a68efc       2024-08-31
# ...           ...                                   ...              ...
# 49993  CUST117199  0265b56d-44bc-4342-a50b-0e298dd73063       2024-10-20
# 49994  CUST115955  c7e837fb-11b8-44d3-a093-45c899cfe38c       2023-11-22
# 49995  CUST114840  1d4b1017-e8a1-4a7b-94d1-63e90b05d665       2024-12-29
# 49996  CUST103055  2984426c-6d0b-437c-9a13-84bf3244c6d4       2022-06-17
# 49997  CUST119886  cdbc7ad8-0f23-46c4-aaca-619053ad5605       2024-12-14
#
#             loan_type  loan_amount_requested  loan_tenure_months  \
# ...

# %%
df.isin(['Car Loan', 'Education Loan'])
# Out:
#        customer_id  application_id  application_date  loan_type  \
# 0            False           False             False      False
# 1            False           False             False       True
# 2            False           False             False       True
# 3            False           False             False       True
# 4            False           False             False      False
# ...            ...             ...               ...        ...
# 49995        False           False             False       True
# 49996        False           False             False       True
# 49997        False           False             False       True
# 49998        False           False             False      False
# 49999        False           False             False      False
#
#        loan_amount_requested  loan_tenure_months  interest_rate_offered  \
# 0                      False               False                  False
# ...

# %%
df = df.set_index('customer_id')

# %%
df.at['CUST109427', 'loan_amount_requested']
# Out:
# customer_id
# CUST109427    604000.0
# CUST109427    913000.0
# CUST109427    664000.0
# CUST109427    453000.0
# CUST109427    408000.0
# CUST109427    538000.0
# CUST109427    100000.0
# CUST109427    624000.0
# Name: loan_amount_requested, dtype: float64

# %%
cols_needed = ['customer_id', 'loan_type', 'loan_amount_requested']
df_small = df_loan_applications.filter(items=cols_needed)
print(df_small)
# Out:
#       customer_id       loan_type  loan_amount_requested
# 0      CUST109427   Business Loan               604000.0
# 1      CUST106146        Car Loan               100000.0
# 2      CUST100674  Education Loan               431000.0
# 3      CUST106466        Car Loan               324000.0
# 4      CUST112319   Personal Loan               100000.0
# ...           ...             ...                    ...
# 49995  CUST114840  Education Loan               381000.0
# 49996  CUST103055  Education Loan               736000.0
# 49997  CUST119886        Car Loan               436000.0
# 49998  CUST109088   Business Loan               827000.0
# 49999  CUST113445       Home Loan               100000.0
#
# [50000 rows x 3 columns]

# %%
df_interest = df.filter(like='interest')
print(df_interest)
# Out:
#              interest_rate_offered
# customer_id
# CUST109427                   11.66
# CUST106146                   13.62
# CUST100674                   11.40
# CUST106466                   10.36
# CUST112319                   14.14
# ...                            ...
# CUST114840                   12.05
# CUST103055                   11.03
# CUST119886                   10.98
# CUST109088                   16.18
# CUST113445                    9.44
#
# [50000 rows x 1 columns]

# %%
df_loan_cols = df.filter(regex='loan')
print(df_loan_cols)
# Out:
#                   loan_type  loan_amount_requested  loan_tenure_months  \
# customer_id
# CUST109427    Business Loan               604000.0                  12
# CUST106146         Car Loan               100000.0                 240
# CUST100674   Education Loan               431000.0                  60
# CUST106466         Car Loan               324000.0                 120
# CUST112319    Personal Loan               100000.0                  36
# ...                     ...                    ...                 ...
# CUST114840   Education Loan               381000.0                  24
# CUST103055   Education Loan               736000.0                 120
# CUST119886         Car Loan               436000.0                  12
# CUST109088    Business Loan               827000.0                  24
# CUST113445        Home Loan               100000.0                  24
#
#                 purpose_of_loan loan_status
# customer_id
# ...

# %%
df_declined = df.query("loan_status == 'Declined' and loan_amount_requested  >= 50000")
df_declined
# Out:
#                                    application_id application_date  \
# customer_id
# CUST106466   a61337d4-ba04-4a68-b492-2cb8266e6ed7       2024-07-09
# CUST112319   a8d1639e-170b-41b2-826a-55c7dae38d16       2023-11-20
# CUST106264   e0b509dc-5357-427d-bd69-681308a68efc       2024-08-31
# CUST116366   d4460e0d-0d9d-448a-8a78-dfa169b1816d       2024-04-12
# CUST114085   beaca2c2-6779-477f-b9b7-78057e3c126b       2024-06-23
# ...                                           ...              ...
# CUST101224   e1bcb9de-02c1-4454-b4e3-39d0d68a6e71       2024-11-15
# CUST110102   61500afa-7f09-4e27-89e2-db2053bfb73e       2023-07-21
# CUST109084   bca9b62a-7eb2-4230-aea3-c67fa3c9e77a       2023-09-16
# CUST115603   4150e40a-7ab6-4ebd-a547-6938990ace07       2024-08-30
# CUST118628   5c2ff689-ef1a-417e-8cff-a07d716f12df       2023-03-28
#
#                   loan_type  loan_amount_requested  loan_tenure_months  \
# customer_id
# ...

# %% [markdown]
# | Function   | Used for                       | Example                                        |
# | ---------- | ------------------------------ | ---------------------------------------------- |
# | `query()`  | Row filter by string expr      | `df.query('Age > 30 and Gender=="Male"')`      |
# | `filter()` | Select cols/rows by name/regex | `df.filter(regex='^loan', axis=1)`             |
# | `isin()`   | Check membership               | `df[df['loan_type'].isin(['Car', 'Edu'])]`     |
# | `at[]`     | Single value by label          | `df.at['CUST109427', 'loan_amount_requested']` |

# %% [markdown]
# | Purpose                 | Example                            |
# | ----------------------- | ---------------------------------- |
# | Single col select       | `df['Name']`                       |
# | Multi col select        | `df[['Name', 'Age']]`              |
# | Row by label            | `df.loc[2]`                        |
# | Row by position         | `df.iloc[2]`                       |
# | Row+col slice by label  | `df.loc[2, 'Name']`                |
# | Row+col slice by pos    | `df.iloc[2, 0]`                    |
# | Boolean condition       | `df[df['Age'] > 30]`               |
# | Query string            | `df.query('Age > 30')`             |
# | Filter columns by regex | `df.filter(regex='^A', axis=1)`    |
# | Membership check        | `df[df['Name'].isin(['A','B'])]`   |
# | Fast scalar access      | `df.at[2, 'Name']` / `df.iat[2,0]` |
