# %% [markdown]
# <a href="https://colab.research.google.com/github/svgoudar/My-Data-Science-Roadmap/blob/main/Pandas_and_Numpy/Panda/4.Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_loan= pd.read_csv("https://raw.githubusercontent.com/svgoudar/datasets/refs/heads/main/loan_applications.csv",)
df_tran = pd.read_csv("https://raw.githubusercontent.com/svgoudar/datasets/refs/heads/main/transactions.csv")

# %%
df_loan[df_loan.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [application_id, customer_id, application_date, loan_type, loan_amount_requested, loan_tenure_months, interest_rate_offered, purpose_of_loan, employment_status, monthly_income, cibil_score, existing_emis_monthly, debt_to_income_ratio, property_ownership_status, residential_address, applicant_age, gender, number_of_dependents, loan_status, fraud_flag, fraud_type]
# Index: []
#
# [0 rows x 21 columns]

# %%
# df_loan.isnull().sum()
df_loan[df_loan.isna().any(axis=1)]
# Out:
#                              application_id customer_id application_date  \
# 0      c8bf0bea-70e6-4870-9125-41b8210c527f  CUST109427       2023-04-09
# 1      91224cec-3544-4bc7-ac15-a9792da54c02  CUST106146       2023-09-23
# 2      4efcd02d-4a03-4ab7-9bd1-0ff430493d0c  CUST100674       2023-05-22
# 3      a61337d4-ba04-4a68-b492-2cb8266e6ed7  CUST106466       2024-07-09
# 4      a8d1639e-170b-41b2-826a-55c7dae38d16  CUST112319       2023-11-20
# ...                                     ...         ...              ...
# 49995  1d4b1017-e8a1-4a7b-94d1-63e90b05d665  CUST114840       2024-12-29
# 49996  2984426c-6d0b-437c-9a13-84bf3244c6d4  CUST103055       2022-06-17
# 49997  cdbc7ad8-0f23-46c4-aaca-619053ad5605  CUST119886       2024-12-14
# 49998  46a8f901-8005-4ae7-923e-f9d0dc8e0ae8  CUST109088       2022-12-16
# 49999  6aaf792e-6755-408e-a9ef-4d9bf841864b  CUST113445       2025-03-25
#
#             loan_type  loan_amount_requested  loan_tenure_months  \
# ...

# %%
# df_loan.dropna()              # drop rows with any NaN
# df_loan.dropna(axis=1)         # drop columns with any NaN
# df_loan.dropna(how='all')      # drop rows only if *all* values are NaN
# df_loan.dropna(thresh=3)       # keep rows with at least 3 non-NaNs

df_loan.isna().sum()
# Out:
# application_id                   0
# customer_id                      0
# application_date                 0
# loan_type                        0
# loan_amount_requested            0
# loan_tenure_months               0
# interest_rate_offered            0
# purpose_of_loan                  0
# employment_status                0
# monthly_income                   0
# cibil_score                      0
# existing_emis_monthly            0
# debt_to_income_ratio             0
# property_ownership_status        0
# residential_address              0
# applicant_age                    0
# gender                           0
# number_of_dependents             0
# loan_status                      0
# fraud_flag                       0
# fraud_type                   48974
# dtype: int64

# %%
df_loan[~df_loan['fraud_type'].isnull()].fraud_type.value_counts()
# Out:
# fraud_type
# Synthetic Identity          276
# Income Misrepresentation    270
# Loan Stacking               242
# Transaction Laundering      238
# Name: count, dtype: int64

# %%
# df_loan.drop_duplicates(inplace=True)

# %%
df_loan.columns
# Out:
# Index(['application_id', 'customer_id', 'application_date', 'loan_type',
#        'loan_amount_requested', 'loan_tenure_months', 'interest_rate_offered',
#        'purpose_of_loan', 'employment_status', 'monthly_income', 'cibil_score',
#        'existing_emis_monthly', 'debt_to_income_ratio',
#        'property_ownership_status', 'residential_address', 'applicant_age',
#        'gender', 'number_of_dependents', 'loan_status', 'fraud_flag',
#        'fraud_type'],
#       dtype='object')

# %%
# df_loan.replace(['yes', 'y'], 'Yes') # Look through the entire DataFrame (df_loan), in all columns and all cells.
# df_loan.loan_status.value_counts()
df_loan['gender'] = df_loan['gender'].astype('category')
print(df_loan.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   application_id             50000 non-null  object
#  1   customer_id                50000 non-null  object
#  2   application_date           50000 non-null  object
#  3   loan_type                  50000 non-null  object
#  4   loan_amount_requested      50000 non-null  float64
#  5   loan_tenure_months         50000 non-null  int64
#  6   interest_rate_offered      50000 non-null  float64
#  7   purpose_of_loan            50000 non-null  object
#  8   employment_status          50000 non-null  object
#  9   monthly_income             50000 non-null  float64
#  10  cibil_score                50000 non-null  int64
#  11  existing_emis_monthly      50000 non-null  float64
#  12  debt_to_income_ratio       50000 non-null  float64
# ...

# %%
x = df_loan['fraud_type'].isna().sum().astype(int)
int(x)
# Out:
# 48974

# %%
df_loan['application_date'] = pd.to_datetime(df_loan['application_date'])

# %%
df_loan['Month'] = df_loan['application_date'].dt.strftime('%b')

# %%
df_loan['application_date'].max()
# Out:
# Timestamp('2025-06-04 00:00:00')

# %% [markdown]
# | Task                       | Example usage                               |
# | -------------------------- | ------------------------------------------- |
# | Detect missing             | `df.isnull()`, `df.isnull().sum()`          |
# | Remove rows/cols with NaNs | `df.dropna()`, `df.dropna(axis=1)`          |
# | Fill missing values        | `df.fillna(0)`, `df.fillna(method='ffill')` |
# | Replace specific values    | `df.replace('?', np.nan)`                   |
# | Drop duplicate rows        | `df.drop_duplicates()`                      |
# | Change data type           | `df['col'].astype(int)`                     |
# | Clean strings              | `df['col'].str.strip().str.lower()`         |

# %%
df_loan.where(df_loan['application_date'] > '2023-05-01')
# Out:
#                              application_id customer_id application_date  \
# 0                                       NaN         NaN              NaT
# 1      91224cec-3544-4bc7-ac15-a9792da54c02  CUST106146       2023-09-23
# 2      4efcd02d-4a03-4ab7-9bd1-0ff430493d0c  CUST100674       2023-05-22
# 3      a61337d4-ba04-4a68-b492-2cb8266e6ed7  CUST106466       2024-07-09
# 4      a8d1639e-170b-41b2-826a-55c7dae38d16  CUST112319       2023-11-20
# ...                                     ...         ...              ...
# 49995  1d4b1017-e8a1-4a7b-94d1-63e90b05d665  CUST114840       2024-12-29
# 49996                                   NaN         NaN              NaT
# 49997  cdbc7ad8-0f23-46c4-aaca-619053ad5605  CUST119886       2024-12-14
# 49998                                   NaN         NaN              NaT
# 49999  6aaf792e-6755-408e-a9ef-4d9bf841864b  CUST113445       2025-03-25
#
#             loan_type  loan_amount_requested  loan_tenure_months  \
# ...

# %%
import numpy as np

df_loan.loc[len(df_loan)] = np.nan
# Out:
# /tmp/ipython-input-14-1414664803.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_loan.loc[len(df_loan)] = np.nan
# /tmp/ipython-input-14-1414664803.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_loan.loc[len(df_loan)] = np.nan

# %%
# df_loan = df_loan.append(pd.Series(dtype='object'), ignore_index=True)

new_row = pd.DataFrame([[np.nan]*len(df_loan.columns)], columns=df_loan.columns)
df_loan = pd.concat([df_loan, new_row], ignore_index=True)
# Out:
# /tmp/ipython-input-15-2182975655.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_loan = pd.concat([df_loan, new_row], ignore_index=True)
# /tmp/ipython-input-15-2182975655.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_loan = pd.concat([df_loan, new_row], ignore_index=True)

# %%
df_loan[df_loan.isna().all(axis=1)]
# Out:
#       application_id customer_id application_date loan_type  \
# 50000            NaN         NaN              NaT       NaN
# 50001            NaN         NaN              NaT       NaN
#
#        loan_amount_requested  loan_tenure_months  interest_rate_offered  \
# 50000                    NaN                 NaN                    NaN
# 50001                    NaN                 NaN                    NaN
#
#       purpose_of_loan employment_status  monthly_income  ...  \
# 50000             NaN               NaN             NaN  ...
# 50001             NaN               NaN             NaN  ...
#
#        debt_to_income_ratio  property_ownership_status  residential_address  \
# 50000                   NaN                        NaN                  NaN
# 50001                   NaN                        NaN                  NaN
#
#       applicant_age gender  number_of_dependents loan_status  fraud_flag  \
# ...

# %%
# df_loan.dropna(axis=1,inplace=True)

# %%
# df_loan.dropna(inplace=True)

# %%
df_loan.dropna(how='all', inplace=True)

# %%
df_loan[df_loan.isna().any(axis=1)]
# Out:
#                              application_id customer_id application_date  \
# 0      c8bf0bea-70e6-4870-9125-41b8210c527f  CUST109427       2023-04-09
# 1      91224cec-3544-4bc7-ac15-a9792da54c02  CUST106146       2023-09-23
# 2      4efcd02d-4a03-4ab7-9bd1-0ff430493d0c  CUST100674       2023-05-22
# 3      a61337d4-ba04-4a68-b492-2cb8266e6ed7  CUST106466       2024-07-09
# 4      a8d1639e-170b-41b2-826a-55c7dae38d16  CUST112319       2023-11-20
# ...                                     ...         ...              ...
# 49995  1d4b1017-e8a1-4a7b-94d1-63e90b05d665  CUST114840       2024-12-29
# 49996  2984426c-6d0b-437c-9a13-84bf3244c6d4  CUST103055       2022-06-17
# 49997  cdbc7ad8-0f23-46c4-aaca-619053ad5605  CUST119886       2024-12-14
# 49998  46a8f901-8005-4ae7-923e-f9d0dc8e0ae8  CUST109088       2022-12-16
# 49999  6aaf792e-6755-408e-a9ef-4d9bf841864b  CUST113445       2025-03-25
#
#             loan_type  loan_amount_requested  loan_tenure_months  \
# ...

# %%
df_loan.isna().sum()
# Out:
# application_id                   0
# customer_id                      0
# application_date                 0
# loan_type                        0
# loan_amount_requested            0
# loan_tenure_months               0
# interest_rate_offered            0
# purpose_of_loan                  0
# employment_status                0
# monthly_income                   0
# cibil_score                      0
# existing_emis_monthly            0
# debt_to_income_ratio             0
# property_ownership_status        0
# residential_address              0
# applicant_age                    0
# gender                           0
# number_of_dependents             0
# loan_status                      0
# fraud_flag                       0
# fraud_type                   48974
# Month                            0
# dtype: int64

# %%
df_loan.shape
# Out:
# (50000, 22)

# %%
df_loan['fraud_type'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipython-input-23-898683015.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_loan['fraud_type'].fillna('Unknown', inplace=True)

# %%
df_loan.columns
# Out:
# Index(['application_id', 'customer_id', 'application_date', 'loan_type',
#        'loan_amount_requested', 'loan_tenure_months', 'interest_rate_offered',
#        'purpose_of_loan', 'employment_status', 'monthly_income', 'cibil_score',
#        'existing_emis_monthly', 'debt_to_income_ratio',
#        'property_ownership_status', 'residential_address', 'applicant_age',
#        'gender', 'number_of_dependents', 'loan_status', 'fraud_flag',
#        'fraud_type', 'Month'],
#       dtype='object')

# %%
df_loan['expected_approval'] = df_loan['cibil_score'].apply(lambda x : 'Approved' if x >= 720 else 'Decline')

# %%
df_loan.loc[0]
# Out:
# application_id                            c8bf0bea-70e6-4870-9125-41b8210c527f
# customer_id                                                         CUST109427
# application_date                                           2023-04-09 00:00:00
# loan_type                                                        Business Loan
# loan_amount_requested                                                 604000.0
# loan_tenure_months                                                        12.0
# interest_rate_offered                                                    11.66
# purpose_of_loan                                              Medical Emergency
# employment_status                                                      Retired
# monthly_income                                                         34700.0
# cibil_score                                                              714.0
# existing_emis_monthly                                                   1100.0
# ...

# %%
df_loan.head(3)
# Out:
#                          application_id customer_id application_date  \
# 0  c8bf0bea-70e6-4870-9125-41b8210c527f  CUST109427       2023-04-09
# 1  91224cec-3544-4bc7-ac15-a9792da54c02  CUST106146       2023-09-23
# 2  4efcd02d-4a03-4ab7-9bd1-0ff430493d0c  CUST100674       2023-05-22
#
#         loan_type  loan_amount_requested  loan_tenure_months  \
# 0   Business Loan               604000.0                12.0
# 1        Car Loan               100000.0               240.0
# 2  Education Loan               431000.0                60.0
#
#    interest_rate_offered    purpose_of_loan employment_status  monthly_income  \
# 0                  11.66  Medical Emergency           Retired         34700.0
# 1                  13.62          Education        Unemployed         51600.0
# 2                  11.40  Medical Emergency     Self-Employed         14800.0
#
#    ...  property_ownership_status  \
# 0  ...                     Rented
# 1  ...                      Owned
# ...

# %%
df = pd.merge(df_loan,df_tran,on='customer_id')

# %%
pd.set_option('display.max.columns',None)

# %%
df['interest_rate_offered_clipped'] = df['interest_rate_offered'].clip(10,15)

# %%
df[df['interest_rate_offered'] <= 10].shape
# Out:
# (50316, 39)

# %%
df[df['interest_rate_offered'] >= 15].shape
# Out:
# (1470, 39)

# %%
df[df['interest_rate_offered_clipped'] == 15].shape
# Out:
# (1470, 39)

# %% [markdown]
# | Task                       | Example usage                               |
# | -------------------------- | ------------------------------------------- |
# | Detect missing             | `df.isnull()`, `df.isnull().sum()`          |
# | Remove rows/cols with NaNs | `df.dropna()`, `df.dropna(axis=1)`          |
# | Fill missing values        | `df.fillna(0)`, `df.fillna(method='ffill')` |
# | Replace specific values    | `df.replace('?', np.nan)`                   |
# | Drop duplicate rows        | `df.drop_duplicates()`                      |
# | Change data type           | `df['col'].astype(int)`                     |
# | Clean strings              | `df['col'].str.strip().str.lower()`         |

# %% [markdown]
# | API                     | Description                                                          | Example                        |
# | ----------------------- | -------------------------------------------------------------------- | ------------------------------ |
# | `isnull()` / `isna()`   | Detect missing values → boolean DataFrame. Same function, two names. | `df.isnull()` or `df.isna()`   |
# | `notnull()` / `notna()` | Detect non-missing values.                                           | `df.notnull()` or `df.notna()` |
# | `dropna()` | Drop rows or columns with NaNs. | `df.dropna()` drops rows with any NaNs.                    |
# |            |                                 | `df.dropna(axis=1)` drops columns.                         |
# |            |                                 | `df.dropna(how='all')` drops only if all NaN.              |
# |            |                                 | `df.dropna(thresh=3)` keeps rows with at least 3 non-NaNs. |
# | `fillna()` | Fill NaNs with a scalar, dict, method. | `df.fillna(0)` replaces NaNs with 0.            |
# |            |                                        | `df.fillna({'col1': 0, 'col2':99})` per column. |
# |            |                                        | `df.fillna(method='ffill')` forward fill.       |
# |            |                                        | `df.fillna(method='bfill')` backward fill.      |
# | `replace()` | Replace any specified value. | `df.replace(-1, np.nan)` converts `-1` to `NaN`. |
# |             |                              | `df.replace(['?', 'NA'], np.nan)`                |
# | `interpolate()` | Fill NaNs by interpolation. | `df['col'].interpolate()` does linear interpolation. |
# | `dropna(subset=...)` | Drop rows where specific cols are NaN.             | `df.dropna(subset=['col1'])` |
# | `where`              | Keep values where condition is True; else set NaN. | `df.where(df > 0)`           |
# | `mask`               | Opposite of `where`: set NaN where condition True. | `df.mask(df < 0)`            |
