# %% [markdown]
# ### 🔹 Logistic Regression in Binary Classification
#
# * Goal: find a best-fit line to separate two classes.
# * Problem: What if there are **more than two output categories** (multi-class)?
#
# ---
#
# ### 🔹 Multi-Class Logistic Regression
#
# * Example: 3 categories (Class A, B, C).
# * Logistic regression can be extended using the **One-vs-Rest (OvR)** strategy.
#
# ---
#
# ### 🔹 One-vs-Rest (OvR) Approach
#
# 1. **Idea**: Train multiple binary classifiers, one for each class.
#
#    * For class 1 vs (class 2 + class 3).
#    * For class 2 vs (class 1 + class 3).
#    * For class 3 vs (class 1 + class 2).
# 2. Each model outputs a probability that a new sample belongs to its target class.
# 3. The **final prediction** = class with the highest probability.
#
# ---
#
# ### 🔹 Example Walkthrough
#
# * Input features: f1, f2, f3.
# * Output labels (1, 2, 3) → converted into **one-hot encoding**:
#
#   * Class 1 → \[1,0,0]
#   * Class 2 → \[0,1,0]
#   * Class 3 → \[0,0,1]
# * Train 3 models (M1, M2, M3).
#
#   * M1 trained with output = Class 1.
#   * M2 trained with output = Class 2.
#   * M3 trained with output = Class 3.
#
# ---
#
# ### 🔹 Prediction Phase
#
# * New test sample is passed through all models:
#
#   * M1 → Probability = 0.25
#   * M2 → Probability = 0.20
#   * M3 → Probability = 0.55
# * Since M3 has the highest probability (0.55), the final class = **Category 3**.
#
# ---
#
# ✅ **Key takeaway**:
#
# * Logistic Regression handles multi-class classification using **One-vs-Rest (OvR)** or **One-vs-One (OvO)** strategies.
# * The prediction is made by comparing probabilities from each model and choosing the class with the highest score.
